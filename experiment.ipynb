# %%
# Draw the line graph for xgrammar mean decode time vs batch size
batch_size = [8, 16, 32, 64, 128, 256, 512, 1024]
xgrammar_tbt = [12.938028051498089, 15.772143114036487, 47.88742927794761, 57.046380448848645, 74.54454537655445, 98.643348572102, 162.4707338657785, 285.4167425886114]
origin_tbt = [10.29827356338501, 11.422903537750244, 27.704429626464844, 29.46901559829712, 31.00029945373535, 36.01197957992554, 52.19182252883911, 130.00325637288614]
ours_tbt = [12.367621235463812, 16.78256878907653, 47.94365236128884, 55.694722581183775, 65.49691057753289, 90.20453211904942, 143.83467312516837, 232.1808475187455]

import matplotlib.pyplot as plt
# use red color for xgrammar and blue color for origin, and draw the points
plt.plot(batch_size, xgrammar_tbt, 'ro-', label='XGrammar')
plt.plot(batch_size, ours_tbt, 'go-', label='Ours')
plt.plot(batch_size, origin_tbt, 'bo-', label='Origin')
plt.xlabel('Batch Size')
plt.ylabel('Mean Decode Time (ms)')
plt.title('Mean Decode Time vs Batch Size')
plt.legend()
plt.grid()
plt.show()
