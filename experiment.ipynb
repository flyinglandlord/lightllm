# %%
# Draw the line graph for xgrammar mean decode time vs batch size
batch_size = [8, 16, 32, 64, 128, 256, 512]
xgrammar_tbt = [16.740910360746295, 25.742143114036487, 46.819027339186626, 95.59794229881786, 159.59673952833515, 288.0167938838495, 539.8764654854748]
origin_tbt = [10.29827356338501, 11.422903537750244, 27.704429626464844, 29.46901559829712, 31.00029945373535, 36.01197957992554, 52.19182252883911]

import matplotlib.pyplot as plt
# use red color for xgrammar and blue color for origin, and draw the points
plt.plot(batch_size, xgrammar_tbt, 'ro-', label='XGrammar')
plt.plot(batch_size, origin_tbt, 'bo-', label='Origin')
plt.xlabel('Batch Size')
plt.ylabel('Mean Decode Time (ms)')
plt.title('Mean Decode Time vs Batch Size')
plt.legend()
plt.grid()
plt.show()
